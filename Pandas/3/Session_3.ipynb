# %% [markdown]
# # Session_3

# %%
import pandas as pd

# %%
part_1_2015 = pd.read_csv('World_Happiness_2015_Part1.csv')
part_2_2015 = pd.read_csv('World_Happiness_2015_Part2.csv')
part_3_2015 = pd.read_csv('World_Happiness_2015_Part3.csv')

# %%
regions = pd.read_csv('Regions.csv')

# %%
regions.head(10)
# Out:
#        Country                           Region
# 0  Afghanistan                    Southern Asia
# 1      Albania       Central and Eastern Europe
# 2      Algeria  Middle East and Northern Africa
# 3       Angola               Sub-Saharan Africa
# 4    Argentina      Latin America and Caribbean
# 5      Armenia       Central and Eastern Europe
# 6    Australia        Australia and New Zealand
# 7      Austria                   Western Europe
# 8   Azerbaijan       Central and Eastern Europe
# 9      Bahrain  Middle East and Northern Africa

# %% [markdown]
# # Concatenation

# %%
'yuaan' + 'hussain'
# Out:
# 'yuaanhussain'

# %%
part_1_2015.shape
# Out:
# (50, 11)

# %%
part_2_2015.shape
# Out:
# (50, 11)

# %%
part_3_2015.shape
# Out:
# (58, 11)

# %%
#no of coloumns and rows and column name must similar at a time of concatenation
pd.concat([part_1_2015, part_2_2015])
# Out:
#                    Country  Happiness Rank  Happiness Score  Standard Error  \
# 0              Switzerland               1            7.587         0.03411
# 1                  Iceland               2            7.561         0.04884
# 2                  Denmark               3            7.527         0.03328
# 3                   Norway               4            7.522         0.03880
# 4                   Canada               5            7.427         0.03553
# ..                     ...             ...              ...             ...
# 45  Bosnia and Herzegovina              96            4.949         0.06913
# 46                 Lesotho              97            4.898         0.09438
# 47      Dominican Republic              98            4.885         0.07446
# 48                    Laos              99            4.876         0.06698
# 49                Mongolia             100            4.874         0.03313
#
# ...

# %%
pd.concat([part_1_2015, part_2_2015], keys=['part_1','part_2'])
# Out:
#                           Country  Happiness Rank  Happiness Score  \
# part_1 0              Switzerland               1            7.587
#        1                  Iceland               2            7.561
#        2                  Denmark               3            7.527
#        3                   Norway               4            7.522
#        4                   Canada               5            7.427
# ...                           ...             ...              ...
# part_2 45  Bosnia and Herzegovina              96            4.949
#        46                 Lesotho              97            4.898
#        47      Dominican Republic              98            4.885
#        48                    Laos              99            4.876
#        49                Mongolia             100            4.874
#
#            Standard Error  Economy (GDP per Capita)   Family  \
# part_1 0          0.03411                   1.39651  1.34951
# ...

# %%
pd.concat([part_1_2015, part_2_2015], ignore_index=True)
# Out:
#                    Country  Happiness Rank  Happiness Score  Standard Error  \
# 0              Switzerland               1            7.587         0.03411
# 1                  Iceland               2            7.561         0.04884
# 2                  Denmark               3            7.527         0.03328
# 3                   Norway               4            7.522         0.03880
# 4                   Canada               5            7.427         0.03553
# ..                     ...             ...              ...             ...
# 95  Bosnia and Herzegovina              96            4.949         0.06913
# 96                 Lesotho              97            4.898         0.09438
# 97      Dominican Republic              98            4.885         0.07446
# 98                    Laos              99            4.876         0.06698
# 99                Mongolia             100            4.874         0.03313
#
# ...

# %% [markdown]
# # Skill Test - 1

# %% [markdown]
# Concatenate all three files together

# %%
dataset = pd.concat([part_1_2015, part_2_2015, part_3_2015], ignore_index=True)

# %% [markdown]
# # Skill Test - 2 - Data Analysis

# %% [markdown]
# Which regions has the maximum average Happiness Score

# %%
regions.head()
# Out:
#        Country                           Region
# 0  Afghanistan                    Southern Asia
# 1      Albania       Central and Eastern Europe
# 2      Algeria  Middle East and Northern Africa
# 3       Angola               Sub-Saharan Africa
# 4    Argentina      Latin America and Caribbean

# %%
dataset.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland               1            7.587         0.03411
# 1      Iceland               2            7.561         0.04884
# 2      Denmark               3            7.527         0.03328
# 3       Norway               4            7.522         0.03880
# 4       Canada               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
#this command is just for clearing concept
pd.concat([regions, dataset])
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Afghanistan                    Southern Asia             NaN
# 1        Albania       Central and Eastern Europe             NaN
# 2        Algeria  Middle East and Northern Africa             NaN
# 3         Angola               Sub-Saharan Africa             NaN
# 4      Argentina      Latin America and Caribbean             NaN
# ..           ...                              ...             ...
# 153       Rwanda                              NaN           154.0
# 154        Benin                              NaN           155.0
# 155        Syria                              NaN           156.0
# 156      Burundi                              NaN           157.0
# 157         Togo                              NaN           158.0
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0                NaN             NaN                       NaN      NaN
# ...

# %%
#axis = 0 -> by row
#axis = 1 -> by column
pd.concat([regions, dataset], axis=1)
# Out:
#          Country                           Region      Country  \
# 0    Afghanistan                    Southern Asia  Switzerland
# 1        Albania       Central and Eastern Europe      Iceland
# 2        Algeria  Middle East and Northern Africa      Denmark
# 3         Angola               Sub-Saharan Africa       Norway
# 4      Argentina      Latin America and Caribbean       Canada
# ..           ...                              ...          ...
# 153      Vietnam                Southeastern Asia       Rwanda
# 154        Yemen  Middle East and Northern Africa        Benin
# 155       Zambia               Sub-Saharan Africa        Syria
# 156     Zimbabwe               Sub-Saharan Africa      Burundi
# 157          NaN                              NaN         Togo
#
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# ...

# %% [markdown]
# # Data Merging

# %%
inner_join = regions.merge(dataset, on='Country', how='inner')

# %%
inner_join.head()
# Out:
#        Country                           Region  Happiness Rank  \
# 0  Afghanistan                    Southern Asia             153
# 1      Albania       Central and Eastern Europe              95
# 2      Algeria  Middle East and Northern Africa              68
# 3       Angola               Sub-Saharan Africa             137
# 4    Argentina      Latin America and Caribbean              30
#
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            3.575         0.03084                   0.31982  0.30285
# 1            4.959         0.05013                   0.87867  0.80434
# 2            5.605         0.05099                   0.93929  1.07772
# 3            4.033         0.04758                   0.75778  0.86040
# 4            6.574         0.04612                   1.05351  1.24823
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.30335  0.23414                        0.09719
# ...

# %%
inner_join.shape
# Out:
# (151, 12)

# %%
regions.describe()
# Out:
#             Country              Region
# count           157                 157
# unique          157                  10
# top     Afghanistan  Sub-Saharan Africa
# freq              1                  38

# %%
inner_join[inner_join.Region == 'Southern Asia']['Happiness Score'].mean()
# Out:
# 4.580857142857142

# %% [markdown]
# # Group by

# %%
groupby_region = inner_join.groupby('Region')

# %%
inner_join['Region']
# Out:
# 0                        Southern Asia
# 1           Central and Eastern Europe
# 2      Middle East and Northern Africa
# 3                   Sub-Saharan Africa
# 4          Latin America and Caribbean
#                     ...
# 146        Latin America and Caribbean
# 147                  Southeastern Asia
# 148    Middle East and Northern Africa
# 149                 Sub-Saharan Africa
# 150                 Sub-Saharan Africa
# Name: Region, Length: 151, dtype: object

# %%
groupby_region.get_group('Southern Asia')['Happiness Score'].mean()
# Out:
# 4.580857142857142

# %%
groupby_region['Happiness Score'].mean()
# Out:
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.330789
# North America                      7.273000
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.125647
# Western Europe                     6.689619
# Name: Happiness Score, dtype: float64

# %%
max(groupby_region['Happiness Score'].mean())
# Out:
# 7.285

# %%
min(groupby_region['Happiness Score'].mean())
# Out:
# 4.125647058823529

# %%
groupby_region['Happiness Score'].mean().sort_values()
# Out:
# Region
# Sub-Saharan Africa                 4.125647
# Southern Asia                      4.580857
# Southeastern Asia                  5.317444
# Middle East and Northern Africa    5.330789
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Western Europe                     6.689619
# North America                      7.273000
# Australia and New Zealand          7.285000
# Name: Happiness Score, dtype: float64

# %%
groupby_region['Happiness Score'].mean().sort_values(ascending=False)
# Out:
# Region
# Australia and New Zealand          7.285000
# North America                      7.273000
# Western Europe                     6.689619
# Latin America and Caribbean        6.144682
# Eastern Asia                       5.626167
# Central and Eastern Europe         5.332931
# Middle East and Northern Africa    5.330789
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.125647
# Name: Happiness Score, dtype: float64

# %%
groupby_region['Happiness Score'].mean().sort_values(ascending=False).head(1) #Ans of Skill Test-2
# Out:
# Region
# Australia and New Zealand    7.285
# Name: Happiness Score, dtype: float64

# %%
dataset.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
groupby_region['Happiness Score'].agg(['mean','sum','count'])
# Out:
#                                      mean      sum  count
# Region
# Australia and New Zealand        7.285000   14.570      2
# Central and Eastern Europe       5.332931  154.655     29
# Eastern Asia                     5.626167   33.757      6
# Latin America and Caribbean      6.144682  135.183     22
# Middle East and Northern Africa  5.330789  101.285     19
# North America                    7.273000   14.546      2
# Southeastern Asia                5.317444   47.857      9
# Southern Asia                    4.580857   32.066      7
# Sub-Saharan Africa               4.125647  140.272     34
# Western Europe                   6.689619  140.482     21

# %%
#inner_join.Region.unique()
inner_join['Region'].unique()
# Out:
# array(['Southern Asia', 'Central and Eastern Europe',
#        'Middle East and Northern Africa', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'Australia and New Zealand',
#        'Western Europe', 'Southeastern Asia', 'North America',
#        'Eastern Asia'], dtype=object)

# %%
left_join = regions.merge(dataset, on = 'Country', how = 'left')

# %%
left_join.shape
# Out:
# (157, 12)

# %%
regions.shape
# Out:
# (157, 2)

# %%
left_join[left_join['Happiness Score'].isnull()]
# Out:
#                Country                       Region  Happiness Rank  \
# 13              Belize  Latin America and Caribbean             NaN
# 95             Namibia           Sub-Saharan Africa             NaN
# 112        Puerto Rico  Latin America and Caribbean             NaN
# 124            Somalia           Sub-Saharan Africa             NaN
# 125  Somaliland Region           Sub-Saharan Africa             NaN
# 128        South Sudan           Sub-Saharan Africa             NaN
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)  Family  \
# 13               NaN             NaN                       NaN     NaN
# 95               NaN             NaN                       NaN     NaN
# 112              NaN             NaN                       NaN     NaN
# 124              NaN             NaN                       NaN     NaN
# 125              NaN             NaN                       NaN     NaN
# ...

# %%
right_join = regions.merge(dataset, on = 'Country', how = 'right')

# %%
right_join.shape
# Out:
# (158, 12)

# %%
dataset.shape
# Out:
# (158, 11)

# %%
right_join[right_join['Region'].isnull()]
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 21                       Oman    NaN              22            6.853
# 90          Somaliland region    NaN              91            5.057
# 93                 Mozambique    NaN              94            4.971
# 96                    Lesotho    NaN              97            4.898
# 100                 Swaziland    NaN             101            4.867
# 125                  Djibouti    NaN             126            4.369
# 147  Central African Republic    NaN             148            3.678
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 21          0.05335                   1.36011  1.08182
# 90          0.06161                   0.18847  0.95152
# 93          0.07896                   0.08308  1.02626
# 96          0.09438                   0.37545  1.04103
# 100         0.08742                   0.71206  1.07284
# 125         0.08096                   0.44025  0.59207
# ...
